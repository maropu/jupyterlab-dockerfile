# %%
df = pd.read_parquet('yelp.parquet')
df
# Out:
#        stars      userid    reviewid  businessid      cat109      cat363  \
# 0          5  -869100229 -1968915953   769523113   696087777  1988124248
# 1          4  -869100229   143981813  -758096042   696087777  1988124248
# 2          5  1261659565   538444307  1251550888   696087777  1988124248
# 3          4   330231284  1103275504   399921110   696087777  1988124248
# 4          3   504685766  -795436919 -1717839059   696087777  1988124248
# ...      ...         ...         ...         ...         ...         ...
# 21543      3 -1969616260   536307675  2047128647  1988124248  1988124248
# 21544      3 -1969616260 -1067778897 -1986087952   696087777  1988124248
# 21545      3 -1969616260   195275894   267520646   696087777  1988124248
# 21546      3 -1969616260  1674138925  1692076485  1988124248  1988124248
# 21547      5  1754978464 -1842314142  1737203231  1988124248  1988124248
#
#            cat361      cat366      cat344       cat33  ...  wend2  wend3  \
# ...

# %%
# Selects some features based on LightGBM importance ratios
df = df[['bstars', 'ustars', 'ureviewcnt', 'breviewcnt', 'longitude', 'latitude', 'userid', 'vuseful', 'vcool', 'wday5', 'cat109', 'reviewid', 'businessid']
]

# Applies some transformations
df['breviewcnt'] = np.log10(df['breviewcnt'] + 1)
df['ureviewcnt'] = np.log10(df['ureviewcnt'] + 1)
df = df.drop(['wday5', 'cat109'], axis=1)
df
# Out:
#            bstars  ustars  ureviewcnt  breviewcnt   longitude    latitude  \
# 0      1290556682    4.43    0.107026    0.141716 -1063755642 -1399344675
# 1      1290556682    4.43    0.107026    0.174285 -1805234869  -296905099
# 2      1290556682    3.65    0.135420    0.161115  1596828800 -1846039588
# 3      1290556682    3.77    0.141716    0.174285  -211228047   670334908
# 4      -520823589    3.78    0.114287    0.165442  1701738814 -1993976072
# ...           ...     ...         ...         ...         ...         ...
# 21543  -520823589    3.71    0.185099    0.148483 -1543638721  1583731188
# 21544  1290556682    3.71    0.185099    0.173877  -400764825  1756847365
# 21545  -892273744    3.71    0.185099    0.161115   410253654   911356249
# 21546  1075969934    3.71    0.185099    0.089971 -1294025936 -1457142663
# 21547 -1726093173    4.36    0.126351    0.136614  1460469253   427040562
#
#            userid     vuseful       vcool    reviewid  businessid
# ...

# %%
import pandas_profiling

profile = df.sample(n=100).profile_report(title='Pandas Profiling Report', style={'full_width':True})
profile.to_file(output_file='yelp-pandas-profile.html')
from IPython.display import HTML
HTML('yelp-pandas-profile.html')
# Out:
# <!doctype html><html lang=en><head><meta charset=utf-8><meta name=viewport content="width=device-width, initial-scale=1, shrink-to-fit=no"><meta name=description content="Profile report generated with the `pandas-profiling` Python package"><meta name=author content="Jos Polfliet, Simon Brugman and the open source community."><meta name=generator content="Pandas Profiling 2.3.0"><meta name=url content=https://github.com/pandas-profiling/pandas-profiling><title>Pandas Profiling Report</title><style>
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.get_rejected_variables(threshold=0.9)
# Out:
# []
